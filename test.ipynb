# %%
# LSKA-base
# !python tools/train.py  configs/van/retinanet_van_lska_base_fpn_1x_voc.py

# %%
# inference
from mmdet.apis import DetInferencer

inferencer = DetInferencer('configs/van/retinanet_van_lska_tiny_fpn_1x_voc.py', 'weights/epoch_12.pth')
inferencer('demo/demo.jpg', out_dir="./output")
# Out:
# Loads checkpoint by local backend from path: weights\epoch_12.pth
# d:\miniconda\envs\convnext\lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# d:\miniconda\envs\convnext\lib\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# {'predictions': [{'labels': [6,
#     6,
#     6,
#     6,
#     6,
#     6,
#     6,
#     8,
#     8,
#     14,
#     6,
#     15,
#     3,
#     6,
#     6,
#     3,
#     3,
# ...

# %%
# LSKA-base
# !python tools/train.py  configs/van/mask_rcnn_van_lska_base_fpn_1x_voc.py
